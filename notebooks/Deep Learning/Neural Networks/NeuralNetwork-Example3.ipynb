# %%
# !pip install cerbo
from cerbo.preprocessing import *
from cerbo.DL import NeuralNetwork

# %%
X_train, y_train, X_test= load_dataset('cancer')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical



#model
model = Sequential()
model.add(Dense(6, input_shape = (455,30), activation='relu'))
model.add(Dense(30, activation='softmax'))

# %%
# Out:
# [[1.247e+01 1.860e+01 8.109e+01 ... 1.015e-01 3.014e-01 8.750e-02]
#  [1.894e+01 2.131e+01 1.236e+02 ... 1.789e-01 2.551e-01 6.589e-02]
#  [1.546e+01 1.948e+01 1.017e+02 ... 1.514e-01 2.837e-01 8.019e-02]
#  ...
#  [1.152e+01 1.493e+01 7.387e+01 ... 9.608e-02 2.664e-01 7.809e-02]
#  [1.422e+01 2.785e+01 9.255e+01 ... 8.219e-02 1.890e-01 7.796e-02]
#  [2.073e+01 3.112e+01 1.357e+02 ... 1.659e-01 2.868e-01 8.218e-02]]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-abad339b738e> in <module>()
#       1 print(y_train[0])
# ----> 2 Y_train = to_categorical(y_train)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/utils/np_utils.py in to_categorical(y, num_classes, dtype)
#      67
#      68   """
# ---> 69   y = np.array(y, dtype='int')
#      70   input_shape = y.shape
# ...
