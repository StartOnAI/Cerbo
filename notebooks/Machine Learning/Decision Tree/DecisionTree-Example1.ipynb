# %%
#This is a decision tree regressor for predicting COVID-19 cases the next day using cerbo
import sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import DecisionTreeRegressor
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
# !pip install cerbo
from cerbo.preprocessing import *
from cerbo.ML import DecisionTree
import pandas 
import csv
url = 'https://raw.githubusercontent.com/nytimes/covid-19-data/master/us.csv'
df = pandas.read_csv(url)
inputs = df['cases'].to_numpy()             
outputs = df['deaths'].to_numpy()
df.tail(5)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/externals/six.py:31: FutureWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", FutureWarning)
# Collecting cerbo
#   Downloading https://files.pythonhosted.org/packages/04/2e/5fc7ac09ad73da8a38c50d2b184c3ee7e93d4bab8c46c5cd1e8c5182d3ee/cerbo-0.1.1-py3-none-any.whl
# Installing collected packages: cerbo
# Successfully installed cerbo-0.1.1
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#            date    cases  deaths
# 238  2020-09-15  6614112  195683
# 239  2020-09-16  6653328  196680
# 240  2020-09-17  6698641  197529
# 241  2020-09-18  6747516  198476
# 242  2020-09-19  6789360  199148

# %%
past = 7
s = (len(inputs) , past  * 2)
betterinputs = np.zeros(s)
betteroutputs = np.zeros(len(inputs))

for i in range(len(inputs) - past): # - 0
  temp = np.zeros(past * 2)
  temp[0 : past] = inputs[i : i+ past]
  temp[past:] = outputs[i : i + past] 
  betterinputs[i] = temp
  betteroutputs[i] = inputs[i+past] # + 0
betterinputs = betterinputs[0:len(df) - past] # - 0
betteroutputs = betteroutputs[0:len(df) - past]

# %%
#works with 
preds = DecisionTreeC("r", betterinputs, betteroutputs)

# %%
print(preds[-1])
# Out:
# 4679095.0
