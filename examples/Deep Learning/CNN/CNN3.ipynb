# %%
# !pip install cerbo
# Out:
# Collecting cerbo
#   Downloading https://files.pythonhosted.org/packages/04/2e/5fc7ac09ad73da8a38c50d2b184c3ee7e93d4bab8c46c5cd1e8c5182d3ee/cerbo-0.1.1-py3-none-any.whl
# Installing collected packages: cerbo
# Successfully installed cerbo-0.1.1

# %%
from cerbo.preprocessing import *
from cerbo.DL import *
import keras
from keras.datasets import cifar10
import numpy as np

(x_train, y_train), (x_test, y_test) = cifar10.load_data() #loads in the data
num_classes = 10
y_train = keras.utils.to_categorical(y_train, num_classes) #labels the training data
y_test = keras.utils.to_categorical(y_test, num_classes) #labels the test data
x_train = x_train/255.0
x_test  = x_test/255.0
print(y_train.shape)
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 19s 0us/step
# (50000, 10)

# %%
model = CNN(10, x_train,y_train,x_test,y_test,type='custom')

model.addLayer('conv')
model.addLayer('pool')
model.addLayer('conv')
model.addLayer('pool')
model.addLayer('conv')
model.addLayer('pool')
model.addLayer('fc')
model.addLayer('out','softmax')

test_loss, test_acc = model.compute(loss='categorical_crossentropy',batch=128,num_epochs=20)
print(test_acc)

model.save(name='cnn')
# Out:
# Epoch 1/20
# 391/391 [==============================] - 4s 9ms/step - loss: 1.6413 - accuracy: 0.3953
# Epoch 2/20
# 391/391 [==============================] - 4s 9ms/step - loss: 1.2054 - accuracy: 0.5664
# Epoch 3/20
# 391/391 [==============================] - 4s 9ms/step - loss: 1.0078 - accuracy: 0.6418
# Epoch 4/20
# 391/391 [==============================] - 4s 9ms/step - loss: 0.8923 - accuracy: 0.6846
# Epoch 5/20
# 391/391 [==============================] - 4s 9ms/step - loss: 0.7986 - accuracy: 0.7188
# Epoch 6/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.7326 - accuracy: 0.7425
# Epoch 7/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.6745 - accuracy: 0.7616
# Epoch 8/20
# 391/391 [==============================] - 4s 9ms/step - loss: 0.6253 - accuracy: 0.7787
# Epoch 9/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.5817 - accuracy: 0.7959
# Epoch 10/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.5442 - accuracy: 0.8088
# Epoch 11/20
# 391/391 [==============================] - 4s 9ms/step - loss: 0.5083 - accuracy: 0.8214
# Epoch 12/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.4708 - accuracy: 0.8327
# Epoch 13/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.4445 - accuracy: 0.8441
# Epoch 14/20
# 391/391 [==============================] - 4s 9ms/step - loss: 0.4186 - accuracy: 0.8542
# Epoch 15/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.3855 - accuracy: 0.8646
# Epoch 16/20
# 391/391 [==============================] - 4s 9ms/step - loss: 0.3585 - accuracy: 0.8731
# Epoch 17/20
# 391/391 [==============================] - 4s 9ms/step - loss: 0.3230 - accuracy: 0.8852
# Epoch 18/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.3090 - accuracy: 0.8895
# Epoch 19/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.2863 - accuracy: 0.8972
# Epoch 20/20
# 391/391 [==============================] - 3s 9ms/step - loss: 0.2574 - accuracy: 0.9090
# 0.7305999994277954
