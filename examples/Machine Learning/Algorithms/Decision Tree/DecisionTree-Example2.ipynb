# %%
# !pip install cerbo

# %%
import cerbo
from cerbo.ML import DecisionTree
import sklearn
from sklearn.datasets import load_iris
data = load_iris()

# %%
Y = data.target
X = data.data

# %%
preds = DecisionTree("c", X,Y)
print(preds)
# Out:
# [2 2 2 1 2 2 1 1 2 1 2 2 2 1 1 2 2 2 1 2 2 2 2 2 2 2 1 2 2 2]
