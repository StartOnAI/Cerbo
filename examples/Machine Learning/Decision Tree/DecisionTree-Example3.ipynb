# %%
import sklearn
from sklearn.datasets import load_boston
X, Y = load_boston(return_X_y=True)

# %%
#works after pip upgrade
# !pip install cerbo
import cerbo
from cerbo.ML import DecisionTree
preds = DecisionTree("r", X, Y)

# %%
print(preds)
# Out:
# [ 5.   5.  13.9 50.  13.1 13.3 50.  10.2 13.1 10.2  7.4 13.1 10.4 13.1
#  10.2 10.4 17.8 17.8 21.9 13.1 17.8 13.1 17.8 17.8 10.2 13.1 17.8 10.4
#  21.7 23.2 17.8  6.3 17.8  7.2  7.2 11.3  5.6 15.1 15.1 15.1  7.2  6.3
#  17.8 15.1 15.1 17.8 50.  23.2 23.2 13.3 10.4 13.2 13.2 17.8 17.8 15.1
#  50.  17.4 21.7 23.1 21.2 21.9 13.2 13.1 17.8 13.8 15.2 21.2 21.7 50.
#  17.8 13.1 23.2 13.1 17.8 18.5 21.2 50.  50.  21.9 19.6 23.  13.8 19.6
#  16.2 16.2 16.2 17.1 19.6 18.2 20.3 19.8 19.8 20.  20.3 19.8 20.3 25.
#  20.5 26.7 26.5 20.4]
