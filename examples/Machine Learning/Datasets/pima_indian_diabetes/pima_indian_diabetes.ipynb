# %% [markdown]
# # Imports and Loading Data

# %%
import cerbo.preprocessing as cp
import cerbo.ML as cml

loc = "https://raw.githubusercontent.com/StartOnAI/Cerbo/master/examples/data/pima_indians_diabetes.csv"
data, col_names = cp.load_custom_data(loc, "Outcome", num_features=5, id=False)
# Out:
# 2021-08-05 13:07:04.976553: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2021-08-05 13:07:04.976623: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# # Modelling
#
# Section where we start making our Machine Learning Models

# %% [markdown]
# ## Decision Tree

# %%
dt = cml.DecisionTree(task="c", data=data)
# Out:
# Decision Tree Training Accuracy: 100.0%
# Decision Tree Testing Accuracy:  70.12987012987013%

# %% [markdown]
# ## Random Forest

# %%
rf = cml.RandomForest(task="c", data=data)
# Out:
# Random Forest Training Accuracy: 100.0%
# Random Forest Testing Accuracy: 75.32467532467533%

# %% [markdown]
# ## Boosting

# %% [markdown]
# ### Gradient Boosting

# %%
gb = cml.Boosting(task="c", data=data, algo="gb")
# Out:
# Boosting Training Accuracy: 100.0%
# Boosting Testing Accuracy: 70.995670995671%

# %% [markdown]
# ### XGBoost

# %%
xgb = cml.Boosting(task="c", data=data, algo="xgb")
# Out:
# Boosting Training Accuracy: 99.81378026070763%
# Boosting Testing Accuracy: 74.89177489177489%

# %% [markdown]
# ## Logistic Regression

# %%
log_reg = cml.LogisticReg(data=data)
# Out:
# Logistic Regression Training Accuracy: 78.2122905027933%
# Logistic Regression Testing Accuracy: 74.02597402597402%

# %% [markdown]
# # Conclusions

# %% [raw]
# It only takes 3 Lines(not counting imports) to fully visualize and create a ML model with Cerbo!
